# %%
# !pip install --upgrade mplfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mplfinance in /home/waul/.local/lib/python3.11/site-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in /home/waul/.local/lib/python3.11/site-packages (from mplfinance) (3.8.2)
# Requirement already satisfied: pandas in /home/waul/.local/lib/python3.11/site-packages (from mplfinance) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/waul/.local/lib/python3.11/site-packages (from matplotlib->mplfinance) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/waul/.local/lib/python3.11/site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/waul/.local/lib/python3.11/site-packages (from matplotlib->mplfinance) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/waul/.local/lib/python3.11/site-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /home/waul/.local/lib/python3.11/site-packages (from matplotlib->mplfinance) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /home/waul/.local/lib/python3.11/site-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3/dist-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->mplfinance) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/waul/.local/lib/python3.11/site-packages (from pandas->mplfinance) (2023.4)

# %% [markdown]
# # Importing libraries

# %%
# Basic libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore") 

# For processing
import math
import random
import datetime as dt
import matplotlib.dates as mdates

# For visualization
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc

# Libraries for model training
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import mean_squared_error
# Out:
# /tmp/ipykernel_10420/2436364441.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 2024-02-08 11:34:54.436763: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-08 11:34:54.438204: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-08 11:34:54.458166: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-08 11:34:54.458184: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-08 11:34:54.458750: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-08 11:34:54.462473: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-08 11:34:54.462964: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-08 11:34:55.014288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Reading our dataset
df = pd.read_csv('DS/preprocessed_CAC40.csv', parse_dates=['Date'])
df.head()
# Out:
#    Unnamed: 0   Name       Date   Open  Closing_Price  Daily_High  Daily_Low  \
# 0           0  Accor 2020-04-03  22.99          23.40       23.40      22.99
# 1           1  Accor 2020-04-02  23.91          22.99       23.91      22.99
# 2           2  Accor 2020-04-01  24.10          23.83       24.10      23.83
# 3           3  Accor 2020-03-31  25.04          25.00       25.24      24.99
# 4           4  Accor 2020-03-30  26.50          25.02       26.50      24.99
#
#   Volume
# 0     67
# 1    250
# 2     37
# 3    336
# 4    415

# %% [markdown]
# # Explorartory Data Analysis

# %% [markdown]
# ## Preprocessing

# %%
# Dropping unnecessary column
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# Defining a function that will contain stocks data for a specific company
def specific_data(company, start, end):
    company_data = df[df['Name'] == company]
    date_filtered_data = company_data[(company_data['Date'] > start) & (company_data['Date'] < end)]
    return date_filtered_data

# %%
# Selecting any random company out of our 'Name' column
company_name = random.choice(df['Name'].unique().tolist())
# Setting the start and end date
start_date=dt.datetime(2014,1,1)
end_date=dt.datetime(2020,1,1)

# Calling our function
specific_df = specific_data(company_name, start_date, end_date)

# %%
specific_df.head()
# Out:
#      Name       Date   Open  Closing_Price  Daily_High  Daily_Low Volume
# 67  Accor 2019-12-30  42.10          42.10       42.10      42.10    NaN
# 68  Accor 2019-12-27  41.92          42.20       42.20      41.92    135
# 69  Accor 2019-12-23  41.08          42.09       42.09      41.08     10
# 70  Accor 2019-12-20  41.26          41.26       41.26      41.26    NaN
# 71  Accor 2019-12-19  41.31          41.31       41.31      41.31    NaN

# %% [markdown]
# ## Visualization

# %%
# Line Chart of Closing Prices Over Time

# Convert 'Date' column to datetime
specific_df['Date'] = pd.to_datetime(specific_df['Date'])

plt.figure(figsize=(15, 6))
plt.plot(specific_df['Date'], specific_df['Closing_Price'], marker='.')
plt.title('Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Candlestick Chart

# Convert 'Date' column to matplotlib date format
matplotlib_date = mdates.date2num(specific_df['Date'])

# Create an array of tuples in the required format
ohlc = np.vstack((matplotlib_date, specific_df['Open'], specific_df['Daily_High'], specific_df['Daily_Low'], specific_df['Closing_Price'])).T

plt.figure(figsize=(15, 6))
ax = plt.subplot()
candlestick_ohlc(ax, ohlc, width=0.6, colorup='g', colordown='r')
ax.xaxis_date()
plt.title('Candlestick Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Closing Prices and Moving Average plot

window = 30
plt.figure(figsize=(15, 6))
plt.plot(specific_df['Date'], specific_df['Closing_Price'], label='Closing Price', linewidth=2)
plt.plot(specific_df['Date'], specific_df['Closing_Price'].rolling(window=window).mean(), label=f'{window}-Day Moving Avg', linestyle='--')
plt.title(f'Closing Prices and {window}-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
# Monthly Seasonality of Closing Prices
specific_df['Month'] = specific_df['Date'].dt.month

monthly_average = specific_df.groupby('Month')['Closing_Price'].mean()

plt.figure(figsize=(15, 6))
plt.plot(monthly_average.index, monthly_average.values, marker='o')
plt.title(f'Monthly Seasonality of {company_name}')
plt.xlabel('Months')
plt.ylabel('Average Closing Price')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
specific_df.head()
# Out:
#      Name       Date   Open  Closing_Price  Daily_High  Daily_Low Volume  \
# 67  Accor 2019-12-30  42.10          42.10       42.10      42.10    NaN
# 68  Accor 2019-12-27  41.92          42.20       42.20      41.92    135
# 69  Accor 2019-12-23  41.08          42.09       42.09      41.08     10
# 70  Accor 2019-12-20  41.26          41.26       41.26      41.26    NaN
# 71  Accor 2019-12-19  41.31          41.31       41.31      41.31    NaN
#
#     Month
# 67     12
# 68     12
# 69     12
# 70     12
# 71     12

# %%
new_df = specific_df.reset_index(drop=True)['Open']
new_df.head()
# Out:
# 0    42.10
# 1    41.92
# 2    41.08
# 3    41.26
# 4    41.31
# Name: Open, dtype: float64

# %%
import joblib
# Normalizing our data using MinMaxScaler


scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(new_df.values.reshape(-1, 1))
joblib.dump(scaler, 'scaler.save')
# Out:
# ['scaler.save']

# %%
# Split into training and testing sets
train_size = int(len(scaled_data) * 0.8)  # 80% for training
train_data, test_data = scaled_data[:train_size], scaled_data[train_size:]

# %%
# Define the sequence length (number of past time steps)
n_past = 60

# Prepare sequences for LSTM
X_train, y_train = [], []
for i in range(n_past, len(train_data)):
    X_train.append(train_data[i - n_past:i, 0])
    y_train.append(train_data[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Similarly prepare sequences for the test set
X_test, y_test = [], []
for i in range(n_past, len(test_data)):
    X_test.append(test_data[i - n_past:i, 0])
    y_test.append(test_data[i, 0])
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
print("Training set size:-")
print(X_train.shape), print(y_train.shape)
print("\n")
print("Testing set size:-")
print(X_test.shape), print(y_test.shape)
# Out:
# Training set size:-
# (1151, 60)
# (1151,)
#
#
# Testing set size:-
# (243, 60)
# (243,)
# (None, None)

# %%
# Reshape input data for LSTM([samples, time steps, features])
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# # Model training

# %%
# Initialize a sequential model
model = Sequential()

# First LSTM layer with 50 units, input shape, and return sequences
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))         # Adding dropout to prevent overfitting

# Second LSTM layer with 50 units and return sequences
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

# Third LSTM layer with 50 units
model.add(LSTM(units=50))
model.add(Dropout(0.2))

# Add a dense output layer with one unit
model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 60, 50)            10400
#
#  dropout_15 (Dropout)        (None, 60, 50)            0
#
#  lstm_16 (LSTM)              (None, 60, 50)            20200
#
#  dropout_16 (Dropout)        (None, 60, 50)            0
#
#  lstm_17 (LSTM)              (None, 50)                20200
#
#  dropout_17 (Dropout)        (None, 50)                0
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
# Defining our callbacks
checkpoints = ModelCheckpoint(filepath = 'forecasting_model.h5', save_best_only = True)
# Defining our early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# Training our lstm model
model.fit(X_train, y_train,
          validation_data=(X_test,y_test),
          epochs=100,
          batch_size=32,
          verbose=1,
          callbacks= [checkpoints, early_stopping])
# Out:
# Epoch 1/100
# 36/36 [==============================] - 4s 41ms/step - loss: 0.0495 - val_loss: 0.0090
# Epoch 2/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0105 - val_loss: 0.0051
# Epoch 3/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0083 - val_loss: 0.0044
# Epoch 4/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 5/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0085 - val_loss: 0.0041
# Epoch 6/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0078 - val_loss: 0.0040
# Epoch 7/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0074 - val_loss: 0.0033
# Epoch 8/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0075 - val_loss: 0.0031
# Epoch 9/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0070 - val_loss: 0.0031
# Epoch 10/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 11/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0067 - val_loss: 0.0030
# Epoch 12/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0065 - val_loss: 0.0034
# Epoch 13/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0060 - val_loss: 0.0031
# Epoch 14/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0058 - val_loss: 0.0042
# Epoch 15/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0061 - val_loss: 0.0025
# Epoch 16/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0061 - val_loss: 0.0023
# Epoch 17/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0059 - val_loss: 0.0024
# Epoch 18/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0062 - val_loss: 0.0027
# Epoch 19/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0059 - val_loss: 0.0025
# Epoch 20/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 21/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0053 - val_loss: 0.0025
# Epoch 22/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0058 - val_loss: 0.0023
# Epoch 23/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0062 - val_loss: 0.0025
# Epoch 24/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0048 - val_loss: 0.0022
# Epoch 25/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0048 - val_loss: 0.0020
# Epoch 26/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 27/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0046 - val_loss: 0.0022
# Epoch 28/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0050 - val_loss: 0.0025
# Epoch 29/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0048 - val_loss: 0.0019
# Epoch 30/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0044 - val_loss: 0.0018
# Epoch 31/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 32/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 33/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 34/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0045 - val_loss: 0.0019
# Epoch 35/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 36/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0043 - val_loss: 0.0016
# Epoch 37/100
# 36/36 [==============================] - 1s 33ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 38/100
# 36/36 [==============================] - 1s 31ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 39/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0039 - val_loss: 0.0015
# Epoch 40/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 41/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 42/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 43/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0038 - val_loss: 0.0017
# Epoch 44/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 45/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 46/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 47/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 48/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 49/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 50/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 51/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 52/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 53/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 54/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0034 - val_loss: 0.0011
# Epoch 55/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 56/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0031 - val_loss: 0.0013
# Epoch 57/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0031 - val_loss: 0.0010
# Epoch 58/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0029 - val_loss: 9.8122e-04
# Epoch 59/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 60/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 61/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0028 - val_loss: 9.7524e-04
# Epoch 62/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 63/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0026 - val_loss: 9.4972e-04
# Epoch 64/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0028 - val_loss: 8.6210e-04
# Epoch 65/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0026 - val_loss: 8.8670e-04
# Epoch 66/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0026 - val_loss: 8.1952e-04
# Epoch 67/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0026 - val_loss: 9.0894e-04
# Epoch 68/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0028 - val_loss: 8.4290e-04
# Epoch 69/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 70/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0025 - val_loss: 7.9002e-04
# Epoch 71/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0024 - val_loss: 8.1088e-04
# Epoch 72/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0025 - val_loss: 8.1687e-04
# Epoch 73/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0025 - val_loss: 7.7142e-04
# Epoch 74/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0024 - val_loss: 7.5159e-04
# Epoch 75/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0026 - val_loss: 7.1402e-04
# Epoch 76/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0022 - val_loss: 6.7627e-04
# Epoch 77/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0023 - val_loss: 7.7617e-04
# Epoch 78/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0021 - val_loss: 7.0340e-04
# Epoch 79/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0022 - val_loss: 6.6509e-04
# Epoch 80/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0021 - val_loss: 6.3574e-04
# Epoch 81/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0023 - val_loss: 8.2083e-04
# Epoch 82/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0023 - val_loss: 6.5885e-04
# Epoch 83/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0021 - val_loss: 7.9546e-04
# Epoch 84/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0021 - val_loss: 6.3019e-04
# Epoch 85/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0021 - val_loss: 8.7394e-04
# Epoch 86/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0020 - val_loss: 9.9536e-04
# Epoch 87/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 88/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0020 - val_loss: 6.8191e-04
# Epoch 89/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0020 - val_loss: 6.0465e-04
# Epoch 90/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0020 - val_loss: 6.6439e-04
# Epoch 91/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0021 - val_loss: 6.1712e-04
# Epoch 92/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 5.8748e-04
# Epoch 93/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 5.7135e-04
# Epoch 94/100
# 36/36 [==============================] - 1s 30ms/step - loss: 0.0019 - val_loss: 7.4509e-04
# Epoch 95/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 5.8122e-04
# Epoch 96/100
# 36/36 [==============================] - 1s 30ms/step - loss: 0.0020 - val_loss: 5.4874e-04
# Epoch 97/100
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0021 - val_loss: 6.3344e-04
# Epoch 98/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0018 - val_loss: 5.4461e-04
# Epoch 99/100
# 36/36 [==============================] - 1s 31ms/step - loss: 0.0018 - val_loss: 5.9304e-04
# Epoch 100/100
# 36/36 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 7.1025e-04

# %%
# Let's do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 36/36 [==============================] - 1s 10ms/step
# 8/8 [==============================] - 0s 10ms/step

# %%
# Transform back to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
# Calculate train data RMSE
print(math.sqrt(mean_squared_error(y_train,train_predict)))
# Calculate test data RMSE
print(math.sqrt(mean_squared_error(y_test,test_predict)))
# Out:
# 39.45262565205267
# 34.199434743768876

# %%
# Set the number of previous time steps to consider for plotting
look_back = 60

# Initialize an array for plotting the train predictions
trainPredictPlot = np.empty_like(new_df)
trainPredictPlot[:] = np.nan
# Assign the predicted values to the appropriate location for train predictions
trainPredictPlot[look_back:len(train_predict)+look_back] = train_predict.flatten()

# Initialize an array for plotting the test predictions
testPredictPlot = np.empty_like(new_df)
testPredictPlot[:] = np.nan
# Calculate the starting index for the test predictions
test_start = len(new_df) - len(test_predict)
# Assign the predicted values to the appropriate location for test predictions
testPredictPlot[test_start:] = test_predict.flatten()

# Rescale the scaled data back to its original scale using the scaler
original_scaled_data = scaler.inverse_transform(scaled_data)

# Plotting the baseline data, training predictions, and test predictions
plt.figure(figsize=(15, 6))
plt.plot(original_scaled_data, color='black', label=f"Actual {company_name} price")
plt.plot(trainPredictPlot, color='red', label=f"Predicted {company_name} price(train set)")
plt.plot(testPredictPlot, color='blue', label=f"Predicted {company_name} price(test set)")

plt.title(f"{company_name} share price")
plt.xlabel("time")
plt.ylabel(f"{company_name} share price")
plt.legend()
plt.show()

# %%
# To predict for the next 10 days, you'll need the last n_past days of data
last_sequence = X_test[-1]

# Reshape the last_sequence to match the input shape of the model
last_sequence = last_sequence.reshape(1, n_past, 1)

# Generate predictions for the next 10 days
predictions_next_10_days = []
for _ in range(10):
    next_day_prediction = model.predict(last_sequence)
    predictions_next_10_days.append(next_day_prediction[0, 0])  # Get the predicted value
    last_sequence = np.roll(last_sequence, -1, axis=1)  # Shift the sequence by one day
    last_sequence[0, -1, 0] = next_day_prediction  # Update the last element with the new prediction

# Transform the predictions back to the original scale
predictions_next_10_days = scaler.inverse_transform(np.array(predictions_next_10_days).reshape(-1, 1))

# Print the predictions for the next 10 days
print("Predictions for the next 10 days:")
for i, prediction in enumerate(predictions_next_10_days, start=1):
    print(f"Day {i}: Predicted Price = {prediction[0]}")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predictions for the next 10 days:
# Day 1: Predicted Price = 32.453086853027344
# Day 2: Predicted Price = 32.66996383666992
# Day 3: Predicted Price = 32.97003173828125
# Day 4: Predicted Price = 33.26087188720703
# Day 5: Predicted Price = 33.53400802612305
# Day 6: Predicted Price = 33.790367126464844
# Day 7: Predicted Price = 34.03169250488281
# Day 8: Predicted Price = 34.26008605957031
# Day 9: Predicted Price = 34.47737121582031
# Day 10: Predicted Price = 34.6847038269043

# %%
plt.plot(predictions_next_10_days, marker='*')
plt.title(f'Predicted stock price of {company_name} for next 10 days')
plt.xlabel('Days')
plt.ylabel('Price')
plt.xticks(range(0, 10), ['Day1', 'Day2', 'Day3', 'Day4', 'Day5', 'Day6', 'Day7', 'Day8', 'Day9', 'Day10'])
plt.grid(True)
plt.show()
